# %%
import pandas as pd
import numpy as np



df = pd.read_csv("C:\\Users\Allu\Documents\Joda_ht\listings.csv~\listings.csv")

# %%
df.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'summary',
#        'space', 'description', 'experiences_offered', 'neighborhood_overview',
#        ...
#        'instant_bookable', 'is_business_travel_ready', 'cancellation_policy',
#        'require_guest_profile_picture', 'require_guest_phone_verification',
#        'calculated_host_listings_count',
#        'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms',
#        'calculated_host_listings_count_shared_rooms', 'reviews_per_month'],
#       dtype='object', length=106)

# %%
df.head()
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0  1078  https://www.airbnb.com/rooms/1078  20190308173541   2019-03-08
# 1  2265  https://www.airbnb.com/rooms/2265  20190308173541   2019-03-08
# 2  5245  https://www.airbnb.com/rooms/5245  20190308173541   2019-03-08
# 3  5456  https://www.airbnb.com/rooms/5456  20190308173541   2019-03-08
# 4  5769  https://www.airbnb.com/rooms/5769  20190308173541   2019-03-08
#
#                                         name  \
# 0          *UT/Hyde Park Craftsman Apartment
# 1            Zen-East in the Heart of Austin
# 2        Green, Colorful, Clean &  Cozy home
# 3  Walk to 6th, Rainey St and Convention Ctr
# 4                             NW Austin Room
#
#                                              summary  \
# 0  This upstairs apartment is surrounded by trees...
# 1  Zen East is situated in a vibrant & diverse mu...
# 2                                                NaN
# 3  Fabulous location for walking to Convention Ce...
# 4                                                NaN
#
#                                                space  \
# 0  The garage apartment was built in the 1920s an...
# 1  This colorful and clean 1923 house was complet...
# 2  Situated in a vibrant & diverse multicultural ...
# 3  Cute Private Studio apartment located in Willo...
# 4  Looking for a comfortable inexpensive room to ...
#
#                                          description experiences_offered  \
# 0  This upstairs apartment is surrounded by trees...                none
# 1  Zen East is situated in a vibrant & diverse mu...                none
# 2  Situated in a vibrant & diverse multicultural ...                none
# 3  Fabulous location for walking to Convention Ce...                none
# 4  Looking for a comfortable inexpensive room to ...                none
#
#                                neighborhood_overview        ...          \
# 0  Hyde Park is close to downtown, UT, 6th street...        ...
# 1                                                NaN        ...
# 2                                                NaN        ...
# 3  My neighborhood is ideally located if you want...        ...
# 4  Quiet neighborhood with lots of trees and good...        ...
#
#   instant_bookable is_business_travel_ready          cancellation_policy  \
# 0                t                        f                     flexible
# 1                f                        f  strict_14_with_grace_period
# 2                f                        f  strict_14_with_grace_period
# 3                f                        f  strict_14_with_grace_period
# 4                f                        f                     moderate
#
#   require_guest_profile_picture require_guest_phone_verification  \
# 0                             f                                f
# 1                             f                                f
# 2                             f                                f
# 3                             f                                t
# 4                             t                                t
#
#    calculated_host_listings_count  \
# 0                               3
# 1                               3
# 2                               3
# 3                               1
# 4                               1
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            3
# 1                                            2
# 2                                            2
# 3                                            1
# 4                                            0
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            1
# 2                                            1
# 3                                            0
# 4                                            1
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0               1.63
# 1                                            0               0.19
# 2                                            0               0.07
# 3                                            0               3.88
# 4                                            0               2.21
#
# [5 rows x 106 columns]

# %%
df2 = pd.read_csv("C:\\Users\Allu\Documents\Joda_ht\calendar.csv\calendar.csv")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-4-a28b20d8e5dc> in <module>()
# ----> 1 df2 = pd.read_csv("C:\\Users\Allu\Documents\Joda_ht\calendar.csv\calendar.csv")
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# --> 678         return _read(filepath_or_buffer, kwds)
#     679
#     680     parser_f.__name__ = name
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     438
#     439     # Create the parser.
# --> 440     parser = TextFileReader(filepath_or_buffer, **kwds)
#     441
#     442     if chunksize or iterator:
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     785             self.options['has_index_names'] = kwds['has_index_names']
#     786
# --> 787         self._make_engine(self.engine)
#     788
#     789     def close(self):
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1012     def _make_engine(self, engine='c'):
#    1013         if engine == 'c':
# -> 1014             self._engine = CParserWrapper(self.f, **self.options)
#    1015         else:
#    1016             if engine == 'python':
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1706         kwds['usecols'] = self.usecols
#    1707
# -> 1708         self._reader = parsers.TextReader(src, **kwds)
#    1709
#    1710         passed_names = self.names is None
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._get_header()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Calling read(nbytes) on source failed. Try engine='python'.

# %%
df2.columns

# %%
df2.head()

# %%
df3 = pd.read_csv("C:\\Users\Allu\Documents\Joda_ht\calendar.csv\\reviews.csv")

# %%
df3.columns

# %%
df3.head()

# %%
df.count()

# %%
df.count()

# %%
df2.count()

# %%
df3.count()

# %%
df3.groupby('listing_id').count()[['comments']]

# %%
df4 = pd.read_csv("C:\\Users\Allu\Documents\Joda_ht\\austin-weather\\austin_weather.csv")

# %%
df4.head()

# %%
df4_lower = df4.rename(str.lower, axis='columns')

# %%
df34 = df3.merge(df4_lower, how='left')
df34.head()
# Out:
#    listing_id       id        date  reviewer_id reviewer_name  \
# 0        1078      142  2008-09-13         1344           Amy
# 1        1078   207074  2011-03-22       451657        Angela
# 2        1078   217779  2011-04-04       473682          Jenn
# 3        1078  6841593  2013-08-26      8153398       Kathryn
# 4        1078  7071134  2013-09-05       420381          Rita
#
#                                             comments  temphighf  tempavgf  \
# 0  A fabulously cozy place!  It was slightly diff...        NaN       NaN
# 1                    perfect!---:)  Will stay again!        NaN       NaN
# 2  I had a great stay at Brian's garden apartment...        NaN       NaN
# 3  The reservation was canceled 19 days before ar...        NaN       NaN
# 4  Fantastic Experience!  My daughter and I staye...        NaN       NaN
#
#    templowf dewpointhighf  ...   sealevelpressureavginches  \
# 0       NaN           NaN  ...                         NaN
# 1       NaN           NaN  ...                         NaN
# 2       NaN           NaN  ...                         NaN
# 3       NaN           NaN  ...                         NaN
# 4       NaN           NaN  ...                         NaN
#
#   sealevelpressurelowinches visibilityhighmiles visibilityavgmiles  \
# 0                       NaN                 NaN                NaN
# 1                       NaN                 NaN                NaN
# 2                       NaN                 NaN                NaN
# 3                       NaN                 NaN                NaN
# 4                       NaN                 NaN                NaN
#
#   visibilitylowmiles windhighmph windavgmph windgustmph  \
# 0                NaN         NaN        NaN         NaN
# 1                NaN         NaN        NaN         NaN
# 2                NaN         NaN        NaN         NaN
# 3                NaN         NaN        NaN         NaN
# 4                NaN         NaN        NaN         NaN
#
#   precipitationsuminches events
# 0                    NaN    NaN
# 1                    NaN    NaN
# 2                    NaN    NaN
# 3                    NaN    NaN
# 4                    NaN    NaN
#
# [5 rows x 26 columns]

# %%
df34[df34['tempavgf'].notnull()]

# %%
df34.shape

# %%
df34.listing_id.nunique()

# %%
df34.dtypes

# %%
df.dtypes

# %%
df.isnull().values.any()

# %%
df34.count()

# %%
df34.shape

# %%
df34.shape

# %%
df3.shape

# %%
df34_nonull = df34.dropna(axis=0)
df34_nonull.listing_id.nunique()
# Out:
# 4419

# %%
df34_nonull.shape

# %%
df34_nonull.date.unique()

# %%
df34_nonull.date.nunique()

# %%
dflist_weather = df34_nonull.merge(df,how='left')
dflist_weather.dropna(axis=0)
dflist_weather.listing_id.nunique()
# Out:
# 4419

# %%
dflist_weather.shape
# Out:
# (118250, 131)

# %%
dflist_weather.columns

# %%
dflist_weather.listing_id.nunique()

# %%
pd.set_option('display.max_columns', None)
dflist_weather['listing_id'].nunique()
# Out:
# 4419

# %%
cols = ['listing_id',
        'id',
        'date',
        'comments',
        'tempavgf',
        'dewpointhighf',
        'humidityavgpercent',
        'visibilityavgmiles',
        'windavgmph',
        'precipitationsuminches',
        'events',
        'host_acceptance_rate',
        'host_is_superhost',
        'accommodates',
        'bedrooms',
        'beds',
        'amenities',
        'square_feet',
        'price',
        'number_of_reviews',
        'review_scores_rating',
        'reviews_per_month']
dflw_selected = dflist_weather[cols].copy()

# %%
dflw_selected.shape

# %%
dflw_selected.listing_id.count()

# %%
df.price.nunique()

# %%
df.shape

# %%
dflist_weather.price.nunique()

# %%
dflw_selected.dtypes

# %%
dflw_selected.listing_id.nunique()

# %%
dflw_selected.price.nunique()

# %%
dflw_selected.price.head()

# %%
dflw_selected.price.tail()

# %%
dflw_selected.price.nunique()

# %%
dflw_selected.dtypes

# %%
dflw_selected.host_is_superhost.unique()

# %%
dflw_selected['price'] = dflw_selected['price'].str.replace('$','')
dflw_selected['price'] = dflw_selected['price'].str.replace(',','')

# %%
dflw_selected.price.tail()

# %%
dflw_selected.price = dflw_selected.price.astype(float)

# %%
dflw_selected['host_is_superhost'] = dflw_selected['host_is_superhost'].str.replace('f','0')
dflw_selected['host_is_superhost'] = dflw_selected['host_is_superhost'].fillna('0')
dflw_selected['host_is_superhost'] = dflw_selected['host_is_superhost'].str.replace('t','1')

# %%
dflw_selected['host_is_superhost'].unique()

# %%
dflw_selected.dtypes

# %%
#dflw_selected.dewpointhighf.fillna()
#dflw_selected.dewpointhighf = dflw_selected.dewpointhighf.astype(float)
#dflw_selected.humidityavgpercent = dflw_selected.humidityavgpercent.astype(float)
#dflw_selected.visibilityavgmiles = dflw_selected.visibilityavgmiles.astype(float)
#dflw_selected.windavgmph = dflw_selected.windavgmph.astype(float)
#dflw_selected.precipitationsuminches = dflw_selected.precipitationsuminches.astype(float)
asd = dflw_selected.dropna(subset=['price','tempavgf']).copy()

# %%
dflw_selected.shape
# Out:
# (118250, 22)

# %%
dflw_selected.comments.nunique()
# Out:
# 116579

# %%
kf = dflw_selected.dropna

# %%
kf.shape()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-722d08aebce5> in <module>()
# ----> 1 kf.shape()
#
# AttributeError: 'function' object has no attribute 'shape'

# %%
df34.head()
# Out:
#    listing_id       id        date  reviewer_id reviewer_name  \
# 0        1078      142  2008-09-13         1344           Amy
# 1        1078   207074  2011-03-22       451657        Angela
# 2        1078   217779  2011-04-04       473682          Jenn
# 3        1078  6841593  2013-08-26      8153398       Kathryn
# 4        1078  7071134  2013-09-05       420381          Rita
#
#                                             comments  temphighf  tempavgf  \
# 0  A fabulously cozy place!  It was slightly diff...        NaN       NaN
# 1                    perfect!---:)  Will stay again!        NaN       NaN
# 2  I had a great stay at Brian's garden apartment...        NaN       NaN
# 3  The reservation was canceled 19 days before ar...        NaN       NaN
# 4  Fantastic Experience!  My daughter and I staye...        NaN       NaN
#
#    templowf dewpointhighf dewpointavgf dewpointlowf humidityhighpercent  \
# 0       NaN           NaN          NaN          NaN                 NaN
# 1       NaN           NaN          NaN          NaN                 NaN
# 2       NaN           NaN          NaN          NaN                 NaN
# 3       NaN           NaN          NaN          NaN                 NaN
# 4       NaN           NaN          NaN          NaN                 NaN
#
#   humidityavgpercent humiditylowpercent sealevelpressurehighinches  \
# 0                NaN                NaN                        NaN
# 1                NaN                NaN                        NaN
# 2                NaN                NaN                        NaN
# 3                NaN                NaN                        NaN
# 4                NaN                NaN                        NaN
#
#   sealevelpressureavginches sealevelpressurelowinches visibilityhighmiles  \
# 0                       NaN                       NaN                 NaN
# 1                       NaN                       NaN                 NaN
# 2                       NaN                       NaN                 NaN
# 3                       NaN                       NaN                 NaN
# 4                       NaN                       NaN                 NaN
#
#   visibilityavgmiles visibilitylowmiles windhighmph windavgmph windgustmph  \
# 0                NaN                NaN         NaN        NaN         NaN
# 1                NaN                NaN         NaN        NaN         NaN
# 2                NaN                NaN         NaN        NaN         NaN
# 3                NaN                NaN         NaN        NaN         NaN
# 4                NaN                NaN         NaN        NaN         NaN
#
#   precipitationsuminches events
# 0                    NaN    NaN
# 1                    NaN    NaN
# 2                    NaN    NaN
# 3                    NaN    NaN
# 4                    NaN    NaN

# %%
kf = df34.dropna(axis=0).copy()

# %%
kf.shape
# Out:
# (118250, 26)

# %%
kf.listing_id.nunique()
# Out:
# 4419

# %%
kf['dewpointhighf'] = kf['dewpointhighf'].replace('-', np.nan)
kf['dewpointavgf'] = kf['dewpointavgf'].replace('-', np.nan)
kf['dewpointlowf'] = kf['dewpointlowf'].replace('-', np.nan)
kf['humidityhighpercent'] = kf['humidityhighpercent'].replace('-', np.nan)
kf['humidityavgpercent'] = kf['humidityavgpercent'].replace('-', np.nan)
kf['humiditylowpercent'] = kf['humiditylowpercent'].replace('-', np.nan)
kf['sealevelpressurehighinches'] = kf['sealevelpressurehighinches'].replace('-', np.nan)
kf['sealevelpressureavginches'] = kf['sealevelpressureavginches'].replace('-', np.nan)
kf['sealevelpressurelowinches'] = kf['sealevelpressurelowinches'].replace('-', np.nan)
kf['visibilityhighmiles'] = kf['visibilityhighmiles'].replace('-', np.nan)
kf['visibilityavgmiles'] = kf['visibilityavgmiles'].replace('-', np.nan)
kf['visibilitylowmiles'] = kf['visibilitylowmiles'].replace('-', np.nan)
kf['windhighmph'] = kf['windhighmph'].replace('-', np.nan)
kf['windavgmph'] = kf['windavgmph'].replace('-', np.nan)
kf['windgustmph'] = kf['windgustmph'].replace('-', np.nan)
kf['precipitationsuminches'] = kf['precipitationsuminches'].replace('-', np.nan)
kf['precipitationsuminches'] = kf['precipitationsuminches'].replace('T', np.nan)

# %%
kf['precipitationsuminches'].unique()
# Out:
# array(['0', '0.02', '0.15', nan, '1.34', '0.55', '0.01', '0.13', '0.56',
#        '0.33', '0.63', '2.17', '0.09', '0.41', '0.04', '0.08', '4.79',
#        '0.4', '0.06', '0.05', '0.17', '1.07', '0.49', '0.37', '0.61',
#        '0.86', '0.27', '0.1', '0.24', '1.39', '0.76', '0.18', '1.75',
#        '2.07', '1.12', '0.36', '5.2', '0.93', '1.05', '1.54', '0.34',
#        '0.54', '2.25', '0.92', '1.79', '0.74', '0.16', '0.07', '1.29',
#        '0.67', '0.46', '0.11', '0.31', '0.43', '0.57', '1.09', '0.35',
#        '1.51', '0.2', '2.18', '0.03', '0.14', '0.45', '2.6', '1.46',
#        '0.65', '0.23', '1.19', '0.71', '0.47', '1.41', '0.22', '1.49',
#        '0.75', '0.25', '2.35', '3.33', '0.19', '3.53', '0.26', '4.93',
#        '1.22', '2.45', '0.29', '1.03', '1.32', '0.3', '0.77', '0.52',
#        '0.73', '0.12', '3.66', '0.79', '0.53', '0.51', '2.66', '0.89',
#        '0.66', '1.13', '0.58', '0.68', '3.84', '1.61', '0.94', '1.56',
#        '1.33', '1.57', '0.21', '1.06', '1.17', '1.52', '0.59', '0.98',
#        '1.42'], dtype=object)

# %%
kf['dewpointhighf'].replace('-', np.nan)
kf['temphighf'] = kf['temphighf'].astype(float)
kf['tempavgf'] = kf['tempavgf'].astype(float)
kf['templowf'] = kf['templowf'].astype(float)
kf['dewpointhighf'] = kf['dewpointhighf'].astype(float)
kf['dewpointavgf'] = kf['dewpointavgf'].astype(float)
kf['dewpointlowf'] = kf['dewpointlowf'].astype(float)
kf['humidityhighpercent'] = kf['humidityhighpercent'].astype(float)
kf['humidityavgpercent'] = kf['humidityavgpercent'].astype(float)
kf['humiditylowpercent'] = kf['humiditylowpercent'].astype(float)
kf['sealevelpressurehighinches'] = kf['sealevelpressurehighinches'].astype(float)
kf['sealevelpressureavginches'] = kf['sealevelpressureavginches'].astype(float)
kf['sealevelpressurelowinches'] = kf['sealevelpressurelowinches'].astype(float)
kf['visibilityhighmiles'] = kf['visibilityhighmiles'].astype(float)
kf['visibilityavgmiles'] = kf['visibilityavgmiles'].astype(float)
kf['visibilitylowmiles'] = kf['visibilitylowmiles'].astype(float)
kf['windhighmph'] = kf['windhighmph'].astype(float)
kf['windavgmph'] = kf['windavgmph'].astype(float)
kf['windgustmph'] = kf['windgustmph'].astype(float)
kf['precipitationsuminches'] = kf['precipitationsuminches'].astype(float)

# %%
kf.dtypes
# Out:
# listing_id                      int64
# id                              int64
# date                           object
# reviewer_id                     int64
# reviewer_name                  object
# comments                       object
# temphighf                     float64
# tempavgf                      float64
# templowf                      float64
# dewpointhighf                 float64
# dewpointavgf                  float64
# dewpointlowf                  float64
# humidityhighpercent           float64
# humidityavgpercent            float64
# humiditylowpercent            float64
# sealevelpressurehighinches    float64
# sealevelpressureavginches     float64
# sealevelpressurelowinches     float64
# visibilityhighmiles           float64
# visibilityavgmiles            float64
# visibilitylowmiles            float64
# windhighmph                   float64
# windavgmph                    float64
# windgustmph                   float64
# precipitationsuminches        float64
# events                         object
# dtype: object

# %%
kf.shape
# Out:
# (118250, 26)

# %%
kf.describe()
# Out:
#          listing_id            id   reviewer_id      temphighf       tempavgf  \
# count  1.182500e+05  1.182500e+05  1.182500e+05  118250.000000  118250.000000
# mean   6.175777e+06  9.187094e+07  3.855267e+07      83.009945      72.718326
# std    5.516719e+06  4.868570e+07  3.496051e+07      12.864895      12.180282
# min    1.078000e+03  9.318890e+06  2.900000e+01      32.000000      29.000000
# 25%    1.462557e+06  5.060932e+07  1.064478e+07      76.000000      65.000000
# 50%    4.759081e+06  9.203198e+07  2.761165e+07      84.000000      74.000000
# 75%    1.022930e+07  1.371447e+08  5.745287e+07      93.000000      83.000000
# max    2.248150e+07  1.768442e+08  1.433144e+08     107.000000      93.000000
#
#             templowf  dewpointhighf   dewpointavgf   dewpointlowf  \
# count  118250.000000  117879.000000  117879.000000  117879.000000
# mean       61.923442      63.455857      58.862512      53.469193
# std        12.396445      11.821466      13.003483      14.227624
# min        19.000000      13.000000       8.000000       2.000000
# 25%        54.000000      58.000000      51.000000      44.000000
# 50%        64.000000      67.000000      62.000000      58.000000
# 75%        73.000000      73.000000      69.000000      65.000000
# max        81.000000      80.000000      76.000000      75.000000
#
#        humidityhighpercent  humidityavgpercent  humiditylowpercent  \
# count        118185.000000       118185.000000       118185.000000
# mean             88.254762           67.095080           45.319169
# std              10.668496           12.238014           16.672680
# min              37.000000           27.000000           10.000000
# 25%              85.000000           60.000000           33.000000
# 50%              91.000000           67.000000           44.000000
# 75%              94.000000           75.000000           55.000000
# max             100.000000           97.000000           93.000000
#
#        sealevelpressurehighinches  sealevelpressureavginches  \
# count               117966.000000              117966.000000
# mean                    30.090389                  30.004522
# std                      0.165432                   0.160718
# min                     29.630000                  29.550000
# 25%                     29.980000                  29.900000
# 50%                     30.070000                  29.990000
# 75%                     30.180000                  30.090000
# max                     30.830000                  30.740000
#
#        sealevelpressurelowinches  visibilityhighmiles  visibilityavgmiles  \
# count              117966.000000        117018.000000       117018.000000
# mean                   29.916234             9.996172            9.224162
# std                     0.164220             0.107818            1.366345
# min                    29.410000             5.000000            2.000000
# 25%                    29.820000            10.000000            9.000000
# 50%                    29.900000            10.000000           10.000000
# 75%                    30.000000            10.000000           10.000000
# max                    30.610000            10.000000           10.000000
#
#        visibilitylowmiles    windhighmph     windavgmph    windgustmph  \
# count       117018.000000  118079.000000  118079.000000  117670.000000
# mean             6.857637      13.121156       4.984104      21.329965
# std              3.710426       3.341366       2.048740       5.868913
# min              0.000000       6.000000       1.000000       9.000000
# 25%              3.000000      12.000000       3.000000      17.000000
# 50%              9.000000      13.000000       5.000000      21.000000
# 75%             10.000000      15.000000       6.000000      25.000000
# max             10.000000      29.000000      12.000000      57.000000
#
#        precipitationsuminches
# count           106707.000000
# mean                 0.130608
# std                  0.447421
# min                  0.000000
# 25%                  0.000000
# 50%                  0.000000
# 75%                  0.020000
# max                  5.200000

# %%
import matplotlib.pyplot as plt
kf.hist(bins=20,figsize=(20,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001BA063E1400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA06407940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA06430FD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA06462668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA06488CF8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001BA06488D30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA064E1A58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA06513128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA0651E748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA06546DD8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001BA065774A8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA0659FB38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA065D1208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA065F8898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA06622F28>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001BA066535F8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA0667AC88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA066AD358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA066D49E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA086970B8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001BA086BF748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA086E7DD8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA0871A4A8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA08741B38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA08773208>]],
#       dtype=object)

# %%
# %matplotlib inline
import nltk

# %%
#scatter_cols = ['temphighf', 'tempavgf', 'templowf', 'dewpointhighf', 'dewpointavgf',
       'dewpointlowf', 'humidityhighpercent', 'humidityavgpercent',
       'humiditylowpercent', 'sealevelpressurehighinches',
       'sealevelpressureavginches', 'sealevelpressurelowinches',
       'visibilityhighmiles', 'visibilityavgmiles', 'visibilitylowmiles',
       'windhighmph', 'windavgmph', 'windgustmph', 'precipitationsuminches']
#pd.plotting.scatter_matrix(kf[scatter_cols])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001BA190B7320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA19256438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA19340668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1935A198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1948F588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1948F5C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA197A0C18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA19E50A20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA19DFC400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA197F0A90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA19E283C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1B0C06D8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1B0DB9E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1B0FECF8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1B127048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1B146358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1B168668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1B18A978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1B1AAC88>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1B1CBF98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1B1F42E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1B2175F8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1B239908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1B259C18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1B27BF28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1B2A4278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1B2C4588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1B2E5898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1B30ABA8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1B334EB8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1B365240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1B38E8D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1B3B7F60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1B3E7630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1B410CC0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1B443390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1B468A20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1C46B0F0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1C496780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1C4BEE10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1C4ED4E0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1C515B70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1C546240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1C56E8D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1C598F60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1C5C9630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1C5F2CC0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1C625390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1C64BA20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1C67E0F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1C6A6780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1C6CFE10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1C6FE4E0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1C726B70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1C75B240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1C7828D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1C791A90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1C7BE160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA141647F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1418DE80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA141BE550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA141E8BE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA142192B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA14242940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1426BFD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1429B6A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA142C2D30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA142F5400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA18BBEA90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA18BF1160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA18C177F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA18C41E80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA18C70550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA18C98BE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA18CCB2B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA18CF2940>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001BA18D1CFD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA18D4C6A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA18D75D30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA18DA9400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA18DD1A90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA18E02160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA18E2A7F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA18E51E80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA18E82550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA18EACBE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA18EE12B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA18F07940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA18F30FD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA18F606A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA18F87D30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA18FBB400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA18FE2A90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1C7F5160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1C81E7F0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1C846E80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1C874550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1C89FBE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1C8D02B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1C8F6940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1C920FD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1C9536A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1C97AD30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1C9AF400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1C9D6A90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1CA08160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1CA2E7F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1CA59E80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1CA8A550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1CAB1BE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1CAE32B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1CB0C940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1CB33FD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1CB636A0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1CB8DD30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1CBBE400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1CBE6A90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1CC1B160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1CC417F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1CC6AE80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1CC9B550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1CCC2BE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1CCF42B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1CD1C940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1CD44FD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1CD776A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1CDA0D30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1CDD2400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1CDF9A90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1CE2C160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1CE537F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1CE7CE80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1CEAD550>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1CED6BE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1CF092B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1CF2E940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1CF59FD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1CF886A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1CFB1D30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1CFE2400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1D00BA90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1D03E160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1D0647F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1D08DE80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1D0BF550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1D0E8BE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1D1192B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1D141940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1D169FD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1D19C6A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1D1C4D30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1D1F6400>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1D21DA90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1D24E160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1D2777F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1D2A0E80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1D2D1550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1D2FABE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1D32D2B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1D353940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1D37CFD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1D3AE6A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1D3D5D30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1D407400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1D42EA90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1D462160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1D4887F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1D4B3E80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1D4E3550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1D50BBE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1D53F2B0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1D566940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1D58FFD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1D5C36A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1D5EAD30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1D619400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1D643A90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1D675160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1D69A7F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1D6C5E80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1D6F7550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1D71DBE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1D7512B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1D77B940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1D7A3FD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1D7D26A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1D7FAD30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1D82B400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1D852A90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1D886160>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1D8AE7F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1D8D8E80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1D908550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1D930BE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1D9632B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1D989940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1D9B6FD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1D9E66A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1DA0FD30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1DA40400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1DA66A90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1DA99160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1DAC07F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1DAE9E80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1DB19550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1DB43BE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1DB762B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1DB9C940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1DBC8FD0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1DBF76A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1DC1FD30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1DC50400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1DC78A90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1DCAB160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1DCD37F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1DCFCE80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1DD2C550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1DD54BE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1DD862B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1DDAF940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1DDD9FD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1DE096A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1DE32D30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1DE65400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1DE8BA90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1DEBD160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1DEE57F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1DF0EE80>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1DF3D550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1DF66BE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1DF9A2B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1DFC1940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1DFE8FD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1E01A6A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1E043D30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1E074400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1E09CA90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1E0D1160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1E0F77F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1E120E80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1E150550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1E178BE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1E1AC2B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1E1D3940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1E1FBFD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1E22D6A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1E257D30>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1E287400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1E2B0A90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1E2E3160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1E3087F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1E332E80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1E363550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1E38BBE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1E3BF2B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1E3E7940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1E40FFD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1E43E6A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1E467D30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1E49A400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1E4C1A90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1E4F5160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1E51E7F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1407CB70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA13FB1828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA197DD9B0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001BA197496D8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA196F7C50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1969BAC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA19D564A8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA195EADD8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA19593828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1955C630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1950E0B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA194BF9B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA19482C50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1943BD68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA19CD89E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA193B0550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1937EE80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA193392E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA19305E48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA192C4B38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1927E5C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA091C9860>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001BA191F6470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA191BBA90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA19170DA0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA19133198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1910B940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA190E4EB8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1989B438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA198CA9B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA197893C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA198F44A8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA19884828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA09421080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA08AC8B70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA198C1898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA094BE780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1939C358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1936F9E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1914D0B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA197A8748>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001BA19467DD8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA192B74A8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA190E3B38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA19160208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA19A54898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1977EF28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA194D75F8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA195E7C88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA19334358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA197069E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA19A450B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA199ED748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1E53EDD8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA19F564A8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA19E7EB38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA140CB208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA14050898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA14063F28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA119E05F8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001BA119D5C88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA140F2358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1403C9E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1401B0B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA08BEC748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA08BD0DD8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA13F804A8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA19F09B38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA19ED8208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA13FC6898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA13F9BF28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA13F405F8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA13F08C88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA13EE2CC0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA19F3A9E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA19F110B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA0CAF8748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA0CAC1DD8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA1400D4A8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001BA13E9AB38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA13EB2208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA13E422E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA13E27F28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA12DA15F8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA12D83C88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA12CDF358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA12C529E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA12C45E48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA12BD9748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA12BC7DD8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA12AFA4A8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA12AC0B38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA129E1F60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA126CC898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA126DFF28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA126535F8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA12640C88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BA11BAE668>]],
#       dtype=object)
